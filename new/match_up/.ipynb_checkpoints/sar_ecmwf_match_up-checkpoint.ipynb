# %%
import snappy
from snappy import ProductIO
import datetime
import sys
import os
import gc
import calibrate
import numpy as np
subsetop = snappy.jpy.get_type('org.esa.snap.core.gpf.common.SubsetOp')
wktreader = snappy.jpy.get_type('com.vividsolutions.jts.io.WKTReader')
pixelpos = snappy.jpy.get_type('org.esa.snap.core.datamodel.PixelPos')
geopos = snappy.jpy.get_type('org.esa.snap.core.datamodel.GeoPos')

# %%
def subset(files,  w, bandlist1):
    wkt = wktreader()
    geometries = wkt.read(w)
    subop = subsetop()
    subop.setParameterDefaultValues()
    subop.setSourceProduct(files)
    subop.setGeoRegion(geometries)
    subop.setCopyMetadata(True)
    subop.setBandNames(bandlist1)
    try:
        dd = subop.getTargetProduct()
    except Exception:
        print('exception')
        dd=False
    print('--------success-----')
    return dd

# %%
file_ = ProductIO.readProduct('../ecmwf/east02.nc')

# %%
bandlist=['u10_time1','v10_time1']
w='POLYGON((-68 26,-62 27,-64 33,-69 34,-68 26))'

# %%
file_sb = subset(file_, w, bandlist)
# Out:
# --------success-----

# %%
ProductIO.writeProduct(file_sb, 'file_sb','BEAM-DIMAP')

# %%
band = file_sb.getBand('u10_time1')

# %%
band = file_.getBand('u10_time1')

# %%
band.getImageInfo()

# %%
file_g = file_.getSceneGeoCoding()

# %%
import pandas as pd
import numpy as np

# %%
sar_information = pd.read_csv('./asf-datapool-results-2018-4-4_15-34-49.csv', index_col='Granule Name')

# %%
sar_information.columns
# Out:
# Index([u'Platform', u'Sensor', u'Beam Mode', u'Beam Mode Description',
#        u'Absolute Orbit', u'Relative Orbit', u'Path Number', u'Frame Number',
#        u'Acquisition Date', u'Processing Date', u'Processing Level',
#        u'Start Time', u'End Time', u'Center Lat', u'Center Lon',
#        u'Near Start Lat', u'Near Start Lon', u'Far Start Lat',
#        u'Far Start Lon', u'Near End Lat', u'Near End Lon', u'Far End Lat',
#        u'Far End Lon', u'Faraday Rotation', u'Ascending or Descending?',
#        u'URL', u'Size (MB)', u'Off Nadir Angle', u'Stack Size',
#        u'Baseline Perp.', u'Doppler', u'Stack ID'],
#       dtype='object')

# %%
sar_information.loc[u'S1B_IW_GRDH_1SDV_20171123T222438_20171123T222503_008415_00EE6F_204A', u'Far Start Lon']
# Out:
# -65.270270999999994

# %%
def get_wkt(file_name):
    far_start_lon = sar_information.loc[file_name, u'Far Start Lon']
    far_start_lat = sar_information.loc[file_name, u'Far Start Lat']
    far_end_lon = sar_information.loc[file_name, u'Far Start Lon']
    far_end_lat = sar_information.loc[file_name, u'Far Start Lat']
    near_start_lat = sar_information.loc[file_name, u'Near Start Lat']
    near_start_lon = sar_information.loc[file_name, u'Near Start Lon']
    near_end_lat = sar_information.loc[file_name, u'Near End Lat']
    near_end_lon = sar_information.loc[file_name, u'Near End Lon']
    w = 'POLYGON((%f %f, %f %f, %f %f, %f %f, %f %f))'%(near_start_lon, near_start_lat, near_end_lon, near_end_lat, far_end_lon, far_end_lat, far_start_lon, far_start_lat, near_start_lon, near_start_lat)
    return w

# %%
def get_time(file_):
    file_part_list = file_.split('_')
    time1 = file_part_list[4]
    time_part = time1.split('T')
    date = time_part[0]
    time = time_part[1]
    year = int(date[:4])
    month = int(date[4:6])
    day = int(date[6:])
    hour = int(time[:2])
    minute = int(time[2:4])
    data_list = [year, month, day, hour, minute]
    print('\n------time------')
    print(data_list)
    return data_list

'''
get bandlist
'''
def get_bandlist(file1):
    time= get_time(file1)
    date1 = datetime.datetime(2015, 10,1,0,0,0)
    date2 = datetime.datetime(time[0], time[1], time[2], time[3], time[4],0)
    dd = date2-date1
    band = int(np.around(dd.total_seconds()/60/60/6))+1
    bandlist=['u10_time%d'%band, 'v10_time%d'%band]
    print('\n------bandlist------')
    print(bandlist)
    return bandlist

# %%
sar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1146 entries, 0 to 1145
# Data columns (total 33 columns):
# Granule Name                1146 non-null object
# Platform                    1146 non-null object
# Sensor                      1146 non-null object
# Beam Mode                   1146 non-null object
# Beam Mode Description       1146 non-null object
# Absolute Orbit              1146 non-null int64
# Relative Orbit              1146 non-null int64
# Path Number                 1146 non-null int64
# Frame Number                1146 non-null int64
# Acquisition Date            1146 non-null object
# Processing Date             1146 non-null object
# Processing Level            1146 non-null object
# Start Time                  1146 non-null object
# End Time                    1146 non-null object
# Center Lat                  1146 non-null float64
# Center Lon                  1146 non-null float64
# Near Start Lat              1146 non-null float64
# Near Start Lon              1146 non-null float64
# Far Start Lat               1146 non-null float64
# Far Start Lon               1146 non-null float64
# Near End Lat                1146 non-null float64
# Near End Lon                1146 non-null float64
# Far End Lat                 1146 non-null float64
# Far End Lon                 1146 non-null float64
# Faraday Rotation            3 non-null float64
# Ascending or Descending?    1146 non-null object
# URL                         1146 non-null object
# Size (MB)                   1146 non-null object
# Off Nadir Angle             1146 non-null int64
# Stack Size                  1032 non-null float64
# Baseline Perp.              1032 non-null float64
# Doppler                     1146 non-null int64
# Stack ID                    1032 non-null float64
# dtypes: float64(14), int64(6), object(13)
# memory usage: 295.5+ KB

# %%
sar = sar_information.reset_index()

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-42-6b39a9324e6c> in <module>()
# ----> 1 from tqdm import tqdm
#
# ImportError: No module named tqdm

# %%
for file_n in sar['Granule Name']:
    band = get_bandlist(file_n)
    wk = get_wkt(file_n)
    if sar_information.loc[file_n,'Center Lat'] <60 and sar_information.loc[file_n,'Center Lat']>28 and sar_information.loc[file_n,'Center Lon']>-135 and sar_information.loc[file_n,'Center Lon']<-110:
        f = ProductIO.readProduct('../ecmwf/west02.nc')
    elif sar_information.loc[file_n,'Center Lat'] <50 and sar_information.loc[file_n,'Center Lat']>10 and sar_information.loc[file_n,'Center Lon']>-84 and sar_information.loc[file_n,'Center Lon']<-48:
        f = ProductIO.readProduct('../ecmwf/east02.nc')
    sb = subset(f, wk, band)
    if sb is False:
        f.dispose()
        del sb
        del band
        del wk
        gc.collect()
        continue
    ProductIO.writeProduct(sb, '/Volumes/Yangchao/sar_ecmwf/'+sar_information.loc[file_n, u'Ascending or Descending?']+'_'+file_n, 'BEAM-DIMAP')
    f.dispose()
    sb.dispose()
    del band
    del wk
    gc.collect()
# Out:
# ------time------
# [2017, 11, 23, 22, 24]
#
# ------bandlist------
# ['u10_time3141', 'v10_time3141']
# --------success-----
#
# ------time------
# [2017, 11, 13, 22, 8]
#
# ------bandlist------
# ['u10_time3101', 'v10_time3101']
# --------success-----
#
# ------time------
# [2017, 11, 3, 10, 50]
#
# ------bandlist------
# ['u10_time3059', 'v10_time3059']
# --------success-----
#
# ------time------
# [2017, 7, 25, 9, 57]
#
# ------bandlist------
# ['u10_time2655', 'v10_time2655']
# --------success-----
#
# ------time------
# [2017, 7, 23, 22, 50]
#
# ------bandlist------
# ['u10_time2649', 'v10_time2649']
# --------success-----
#
# ------time------
# [2017, 7, 23, 22, 50]
#
# ------bandlist------
# ['u10_time2649', 'v10_time2649']
# --------success-----
#
# ------time------
# [2017, 7, 23, 22, 49]
#
# ------bandlist------
# ['u10_time2649', 'v10_time2649']
# --------success-----
#
# ------time------
# [2017, 7, 23, 22, 49]
#
# ------bandlist------
# ['u10_time2649', 'v10_time2649']
# --------success-----
#
# ------time------
# [2017, 7, 23, 22, 48]
#
# ------bandlist------
# ['u10_time2649', 'v10_time2649']
# --------success-----
#
# ------time------
# [2017, 7, 23, 22, 46]
#
# ------bandlist------
# ['u10_time2649', 'v10_time2649']
# --------success-----
#
# ------time------
# [2017, 7, 23, 22, 45]
#
# ------bandlist------
# ['u10_time2649', 'v10_time2649']
# --------success-----
#
# ------time------
# [2017, 7, 23, 22, 45]
#
# ------bandlist------
# ['u10_time2649', 'v10_time2649']
# --------success-----
#
# ------time------
# [2017, 7, 23, 10, 13]
#
# ------bandlist------
# ['u10_time2647', 'v10_time2647']
# --------success-----
#
# ------time------
# [2017, 7, 22, 22, 3]
#
# ------bandlist------
# ['u10_time2645', 'v10_time2645']
# --------success-----
#
# ------time------
# [2017, 7, 22, 22, 3]
#
# ------bandlist------
# ['u10_time2645', 'v10_time2645']
# --------success-----
#
# ------time------
# [2017, 7, 21, 23, 5]
#
# ------bandlist------
# ['u10_time2641', 'v10_time2641']
# --------success-----
#
# ------time------
# [2017, 7, 21, 23, 4]
#
# ------bandlist------
# ['u10_time2641', 'v10_time2641']
# --------success-----
#
# ------time------
# [2017, 7, 21, 23, 4]
#
# ------bandlist------
# ['u10_time2641', 'v10_time2641']
# --------success-----
#
# ------time------
# [2017, 7, 21, 23, 4]
#
# ------bandlist------
# ['u10_time2641', 'v10_time2641']
# --------success-----
#
# ------time------
# [2017, 7, 21, 23, 3]
#
# ------bandlist------
# ['u10_time2641', 'v10_time2641']
# --------success-----
#
# ------time------
# [2017, 7, 21, 23, 3]
#
# ------bandlist------
# ['u10_time2641', 'v10_time2641']
# --------success-----
#
# ------time------
# [2017, 7, 21, 23, 2]
#
# ------bandlist------
# ['u10_time2641', 'v10_time2641']
# --------success-----
#
# ------time------
# [2017, 7, 20, 22, 20]
#
# ------bandlist------
# ['u10_time2637', 'v10_time2637']
# --------success-----
#
# ------time------
# [2017, 7, 20, 22, 20]
#
# ------bandlist------
# ['u10_time2637', 'v10_time2637']
# --------success-----
#
# ------time------
# [2017, 7, 20, 9, 49]
#
# ------bandlist------
# ['u10_time2635', 'v10_time2635']
# --------success-----
#
# ------time------
# [2017, 7, 20, 9, 49]
#
# ------bandlist------
# ['u10_time2635', 'v10_time2635']
# --------success-----
#
# ------time------
# [2017, 7, 19, 23, 20]
#
# ------bandlist------
# ['u10_time2633', 'v10_time2633']
# --------success-----
#
# ------time------
# [2017, 7, 19, 23, 20]
#
# ------bandlist------
# ['u10_time2633', 'v10_time2633']
# --------success-----
#
# ------time------
# [2017, 7, 18, 22, 42]
#
# ------bandlist------
# ['u10_time2629', 'v10_time2629']
# --------success-----
#
# ------time------
# [2017, 7, 18, 22, 41]
#
# ------bandlist------
# ['u10_time2629', 'v10_time2629']
# --------success-----
#
# ------time------
# [2017, 7, 18, 22, 41]
#
# ------bandlist------
# ['u10_time2629', 'v10_time2629']
# --------success-----
#
# ------time------
# [2017, 7, 18, 22, 41]
#
# ------bandlist------
# ['u10_time2629', 'v10_time2629']
# --------success-----
#
# ------time------
# [2017, 7, 18, 22, 40]
#
# ------bandlist------
# ['u10_time2629', 'v10_time2629']
# --------success-----
#
# ------time------
# [2017, 7, 18, 22, 37]
#
# ------bandlist------
# ['u10_time2629', 'v10_time2629']
# --------success-----
#
# ------time------
# [2017, 7, 18, 22, 37]
#
# ------bandlist------
# ['u10_time2629', 'v10_time2629']
# --------success-----
#
# ------time------
# [2017, 7, 16, 22, 54]
#
# ------bandlist------
# ['u10_time2621', 'v10_time2621']
# --------success-----
#
# ------time------
# [2017, 7, 16, 10, 21]
#
# ------bandlist------
# ['u10_time2619', 'v10_time2619']
# --------success-----
#
# ------time------
# [2017, 7, 16, 10, 21]
#
# ------bandlist------
# ['u10_time2619', 'v10_time2619']
# --------success-----
#
# ------time------
# [2017, 7, 15, 9, 41]
#
# ------bandlist------
# ['u10_time2615', 'v10_time2615']
# --------success-----
#
# ------time------
# [2017, 7, 14, 23, 13]
#
# ------bandlist------
# ['u10_time2613', 'v10_time2613']
# --------success-----
#
# ------time------
# [2017, 7, 14, 23, 12]
#
# ------bandlist------
# ['u10_time2613', 'v10_time2613']
# --------success-----
#
# ------time------
# [2017, 7, 14, 23, 12]
#
# ------bandlist------
# ['u10_time2613', 'v10_time2613']
# --------success-----
#
# ------time------
# [2017, 7, 14, 23, 12]
#
# ------bandlist------
# ['u10_time2613', 'v10_time2613']
# --------success-----
#
# ------time------
# [2017, 7, 14, 23, 11]
#
# ------bandlist------
# ['u10_time2613', 'v10_time2613']
# --------success-----
#
# ------time------
# [2017, 7, 13, 22, 34]
#
# ------bandlist------
# ['u10_time2609', 'v10_time2609']
# --------success-----
#
# ------time------
# [2017, 7, 13, 22, 29]
#
# ------bandlist------
# ['u10_time2609', 'v10_time2609']
# --------success-----
#
# ------time------
# [2017, 7, 13, 22, 28]
#
# ------bandlist------
# ['u10_time2609', 'v10_time2609']
# --------success-----
#
# ------time------
# [2017, 7, 11, 22, 50]
#
# ------bandlist------
# ['u10_time2601', 'v10_time2601']
# --------success-----
#
# ------time------
# [2017, 7, 11, 22, 50]
#
# ------bandlist------
# ['u10_time2601', 'v10_time2601']
# --------success-----
#
# ------time------
# [2017, 7, 11, 22, 49]
#
# ------bandlist------
# ['u10_time2601', 'v10_time2601']
# --------success-----
#
# ------time------
# [2017, 7, 11, 22, 49]
#
# ------bandlist------
# ['u10_time2601', 'v10_time2601']
# --------success-----
#
# ------time------
# [2017, 7, 11, 22, 48]
#
# ------bandlist------
# ['u10_time2601', 'v10_time2601']
# --------success-----
#
# ------time------
# [2017, 7, 11, 22, 46]
#
# ------bandlist------
# ['u10_time2601', 'v10_time2601']
# --------success-----
#
# ------time------
# [2017, 7, 11, 22, 45]
#
# ------bandlist------
# ['u10_time2601', 'v10_time2601']
# --------success-----
#
# ------time------
# [2017, 7, 11, 22, 45]
#
# ------bandlist------
# ['u10_time2601', 'v10_time2601']
# --------success-----
#
# ------time------
# [2017, 7, 10, 22, 3]
#
# ------bandlist------
# ['u10_time2597', 'v10_time2597']
# --------success-----
#
# ------time------
# [2017, 7, 10, 22, 3]
#
# ------bandlist------
# ['u10_time2597', 'v10_time2597']
# --------success-----
#
# ------time------
# [2017, 7, 10, 22, 3]
#
# ------bandlist------
# ['u10_time2597', 'v10_time2597']
# --------success-----
#
# ------time------
# [2017, 7, 9, 23, 5]
#
# ------bandlist------
# ['u10_time2593', 'v10_time2593']
# --------success-----
#
# ------time------
# [2017, 7, 9, 23, 4]
#
# ------bandlist------
# ['u10_time2593', 'v10_time2593']
# --------success-----
#
# ------time------
# [2017, 7, 9, 23, 4]
#
# ------bandlist------
# ['u10_time2593', 'v10_time2593']
# --------success-----
#
# ------time------
# [2017, 7, 9, 23, 4]
#
# ------bandlist------
# ['u10_time2593', 'v10_time2593']
# --------success-----
#
# ------time------
# [2017, 7, 9, 23, 3]
#
# ------bandlist------
# ['u10_time2593', 'v10_time2593']
# --------success-----
#
# ------time------
# [2017, 7, 9, 23, 3]
#
# ------bandlist------
# ['u10_time2593', 'v10_time2593']
# --------success-----
#
# ------time------
# [2017, 7, 9, 23, 2]
#
# ------bandlist------
# ['u10_time2593', 'v10_time2593']
# --------success-----
#
# ------time------
# [2017, 7, 7, 23, 20]
#
# ------bandlist------
# ['u10_time2585', 'v10_time2585']
# --------success-----
#
# ------time------
# [2017, 7, 7, 23, 20]
#
# ------bandlist------
# ['u10_time2585', 'v10_time2585']
# --------success-----
#
# ------time------
# [2017, 7, 6, 22, 37]
#
# ------bandlist------
# ['u10_time2581', 'v10_time2581']
# --------success-----
#
# ------time------
# [2017, 7, 6, 22, 37]
#
# ------bandlist------
# ['u10_time2581', 'v10_time2581']
# --------success-----
#
# ------time------
# [2017, 7, 6, 10, 5]
#
# ------bandlist------
# ['u10_time2579', 'v10_time2579']
# --------success-----
#
# ------time------
# [2017, 7, 6, 10, 5]
#
# ------bandlist------
# ['u10_time2579', 'v10_time2579']
# --------success-----
#
# ------time------
# [2017, 7, 4, 22, 54]
#
# ------bandlist------
# ['u10_time2573', 'v10_time2573']
# --------success-----
#
# ------time------
# [2017, 7, 4, 10, 21]
# ------bandlist------
# ['u10_time2571', 'v10_time2571']
# --------success-----
#
# ------time------
# [2017, 7, 4, 10, 21]
#
# ------bandlist------
# ['u10_time2571', 'v10_time2571']
# --------success-----
#
# ------time------
# [2017, 7, 3, 9, 41]
#
# ------bandlist------
# ['u10_time2567', 'v10_time2567']
# --------success-----
#
# ------time------
# [2017, 7, 2, 23, 13]
#
# ------bandlist------
# ['u10_time2565', 'v10_time2565']
# --------success-----
#
# ------time------
# [2017, 7, 2, 23, 12]
#
# ------bandlist------
# ['u10_time2565', 'v10_time2565']
# --------success-----
#
# ------time------
# [2017, 7, 2, 23, 12]
#
# ------bandlist------
# ['u10_time2565', 'v10_time2565']
# --------success-----
#
# ------time------
# [2017, 7, 2, 23, 11]
#
# ------bandlist------
# ['u10_time2565', 'v10_time2565']
# --------success-----
#
# ------time------
# [2017, 7, 1, 22, 34]
#
# ------bandlist------
# ['u10_time2561', 'v10_time2561']
# --------success-----
#
# ------time------
# [2017, 7, 1, 9, 57]
#
# ------bandlist------
# ['u10_time2559', 'v10_time2559']
# --------success-----
#
# ------time------
# [2017, 7, 1, 9, 57]
#
# ------bandlist------
# ['u10_time2559', 'v10_time2559']
# --------success-----
#
# ------time------
# [2017, 6, 29, 22, 50]
#
# ------bandlist------
# ['u10_time2553', 'v10_time2553']
# --------success-----
#
# ------time------
# [2017, 6, 29, 22, 50]
#
# ------bandlist------
# ['u10_time2553', 'v10_time2553']
# --------success-----
#
# ------time------
# [2017, 6, 29, 22, 49]
#
# ------bandlist------
# ['u10_time2553', 'v10_time2553']
# --------success-----
#
# ------time------
# [2017, 6, 29, 22, 49]
#
# ------bandlist------
# ['u10_time2553', 'v10_time2553']
# --------success-----
#
# ------time------
# [2017, 6, 29, 22, 48]
#
# ------bandlist------
# ['u10_time2553', 'v10_time2553']
# --------success-----
#
# ------time------
# [2017, 6, 29, 22, 46]
#
# ------bandlist------
# ['u10_time2553', 'v10_time2553']
# --------success-----
#
# ------time------
# [2017, 6, 29, 22, 45]
#
# ------bandlist------
# ['u10_time2553', 'v10_time2553']
# --------success-----
#
# ------time------
# [2017, 6, 29, 10, 13]
#
# ------bandlist------
# ['u10_time2551', 'v10_time2551']
# --------success-----
#
# ------time------
# [2017, 6, 28, 22, 3]
#
# ------bandlist------
# ['u10_time2549', 'v10_time2549']
# --------success-----
#
# ------time------
# [2017, 6, 28, 22, 3]
#
# ------bandlist------
# ['u10_time2549', 'v10_time2549']
# --------success-----
#
# ------time------
# [2017, 6, 28, 22, 3]
#
# ------bandlist------
# ['u10_time2549', 'v10_time2549']
# --------success-----
#
# ------time------
# [2017, 6, 27, 23, 5]
#
# ------bandlist------
# ['u10_time2545', 'v10_time2545']
# --------success-----
#
# ------time------
# [2017, 6, 27, 23, 4]
#
# ------bandlist------
# ['u10_time2545', 'v10_time2545']
# --------success-----
#
# ------time------
# [2017, 6, 27, 23, 4]
#
# ------bandlist------
# ['u10_time2545', 'v10_time2545']
# --------success-----
#
# ------time------
# [2017, 6, 27, 23, 4]
#
# ------bandlist------
# ['u10_time2545', 'v10_time2545']
# --------success-----
#
# ------time------
# [2017, 6, 27, 23, 3]
#
# ------bandlist------
# ['u10_time2545', 'v10_time2545']
# --------success-----
#
# ------time------
# [2017, 6, 27, 23, 3]
#
# ------bandlist------
# ['u10_time2545', 'v10_time2545']
# --------success-----
#
# ------time------
# [2017, 6, 27, 23, 2]
#
# ------bandlist------
# ['u10_time2545', 'v10_time2545']
# --------success-----
#
# ------time------
# [2017, 6, 26, 22, 20]
#
# ------bandlist------
# ['u10_time2541', 'v10_time2541']
# --------success-----
#
# ------time------
# [2017, 6, 26, 22, 20]
#
# ------bandlist------
# ['u10_time2541', 'v10_time2541']
# --------success-----
#
# ------time------
# [2017, 6, 26, 9, 49]
#
# ------bandlist------
# ['u10_time2539', 'v10_time2539']
# --------success-----
#
# ------time------
# [2017, 6, 26, 9, 49]
#
# ------bandlist------
# ['u10_time2539', 'v10_time2539']
# --------success-----
#
# ------time------
# [2017, 6, 25, 23, 20]
#
# ------bandlist------
# ['u10_time2537', 'v10_time2537']
# --------success-----
#
# ------time------
# [2017, 6, 25, 23, 20]
#
# ------bandlist------
# ['u10_time2537', 'v10_time2537']
# --------success-----
#
# ------time------
# [2017, 6, 24, 22, 42]
#
# ------bandlist------
# ['u10_time2533', 'v10_time2533']
# --------success-----
#
# ------time------
# [2017, 6, 24, 22, 41]
#
# ------bandlist------
# ['u10_time2533', 'v10_time2533']
# --------success-----
#
# ------time------
# [2017, 6, 24, 22, 41]
#
# ------bandlist------
# ['u10_time2533', 'v10_time2533']
# --------success-----
#
# ------time------
# [2017, 6, 24, 22, 41]
#
# ------bandlist------
# ['u10_time2533', 'v10_time2533']
# --------success-----
#
# ------time------
# [2017, 6, 24, 22, 40]
#
# ------bandlist------
# ['u10_time2533', 'v10_time2533']
# --------success-----
#
# ------time------
# [2017, 6, 24, 22, 37]
#
# ------bandlist------
# ['u10_time2533', 'v10_time2533']
# --------success-----
#
# ------time------
# [2017, 6, 24, 22, 37]
#
# ------bandlist------
# ['u10_time2533', 'v10_time2533']
# --------success-----
#
# ------time------
# [2017, 6, 24, 10, 5]
#
# ------bandlist------
# ['u10_time2531', 'v10_time2531']
# --------success-----
#
# ------time------
# [2017, 6, 24, 10, 5]
#
# ------bandlist------
# ['u10_time2531', 'v10_time2531']
# --------success-----
#
# ------time------
# [2017, 6, 22, 22, 54]
#
# ------bandlist------
# ['u10_time2525', 'v10_time2525']
# --------success-----
#
# ------time------
# [2017, 6, 22, 10, 21]
#
# ------bandlist------
# ['u10_time2523', 'v10_time2523']
# --------success-----
#
# ------time------
# [2017, 6, 22, 10, 21]
#
# ------bandlist------
# ['u10_time2523', 'v10_time2523']
# --------success-----
#
# ------time------
# [2017, 6, 21, 9, 41]
#
# ------bandlist------
# ['u10_time2519', 'v10_time2519']
# --------success-----
#
# ------time------
# [2017, 6, 20, 23, 13]
#
# ------bandlist------
# ['u10_time2517', 'v10_time2517']
# --------success-----
#
# ------time------
# [2017, 6, 20, 23, 12]
#
# ------bandlist------
# ['u10_time2517', 'v10_time2517']
# --------success-----
#
# ------time------
# [2017, 6, 20, 23, 12]
#
# ------bandlist------
# ['u10_time2517', 'v10_time2517']
# --------success-----
#
# ------time------
# [2017, 6, 20, 23, 11]
#
# ------bandlist------
# ['u10_time2517', 'v10_time2517']
# --------success-----
#
# ------time------
# [2017, 6, 20, 23, 11]
#
# ------bandlist------
# ['u10_time2517', 'v10_time2517']
# --------success-----
#
# ------time------
# [2017, 6, 19, 22, 34]
#
# ------bandlist------
# ['u10_time2513', 'v10_time2513']
# --------success-----
#
# ------time------
# [2017, 6, 19, 22, 29]
#
# ------bandlist------
# ['u10_time2513', 'v10_time2513']
# --------success-----
#
# ------time------
# [2017, 6, 19, 22, 28]
#
# ------bandlist------
# ['u10_time2513', 'v10_time2513']
# --------success-----
#
# ------time------
# [2017, 6, 19, 9, 57]
#
# ------bandlist------
# ['u10_time2511', 'v10_time2511']
# --------success-----
#
# ------time------
# [2017, 6, 19, 9, 57]
#
# ------bandlist------
# ['u10_time2511', 'v10_time2511']
# --------success-----
#
# ------time------
# [2017, 6, 17, 22, 46]
#
# ------bandlist------
# ['u10_time2505', 'v10_time2505']
# --------success-----
#
# ------time------
# [2017, 6, 17, 22, 45]
#
# ------bandlist------
# ['u10_time2505', 'v10_time2505']
# --------success-----
#
# ------time------
# [2017, 6, 17, 22, 45]
#
# ------bandlist------
# ['u10_time2505', 'v10_time2505']
# --------success-----
#
# ------time------
# [2017, 6, 16, 22, 3]
#
# ------bandlist------
# ['u10_time2501', 'v10_time2501']
# --------success-----
#
# ------time------
# [2017, 6, 16, 22, 3]
#
# ------bandlist------
# ['u10_time2501', 'v10_time2501']
# --------success-----
#
# ------time------
# [2017, 6, 15, 23, 4]
#
# ------bandlist------
# ['u10_time2497', 'v10_time2497']
# --------success-----
#
# ------time------
# [2017, 6, 15, 23, 4]
#
# ------bandlist------
# ['u10_time2497', 'v10_time2497']
# --------success-----
#
# ------time------
# [2017, 6, 15, 23, 3]
#
# ------bandlist------
# ['u10_time2497', 'v10_time2497']
# --------success-----
#
# ------time------
# [2017, 6, 15, 23, 3]
#
# ------bandlist------
# ['u10_time2497', 'v10_time2497']
# --------success-----
#
# ------time------
# [2017, 6, 15, 23, 2]
#
# ------bandlist------
# ['u10_time2497', 'v10_time2497']
# --------success-----
#
# ------time------
# [2017, 6, 14, 22, 20]
#
# ------bandlist------
# ['u10_time2493', 'v10_time2493']
# --------success-----
#
# ------time------
# [2017, 6, 14, 22, 20]
#
# ------bandlist------
# ['u10_time2493', 'v10_time2493']
# --------success-----
#
# ------time------
# [2017, 6, 14, 9, 49]
#
# ------bandlist------
# ['u10_time2491', 'v10_time2491']
# --------success-----
#
# ------time------
# [2017, 6, 14, 9, 49]
#
# ------bandlist------
# ['u10_time2491', 'v10_time2491']
# --------success-----
#
# ------time------
# [2017, 6, 13, 23, 20]
#
# ------bandlist------
# ['u10_time2489', 'v10_time2489']
# --------success-----
#
# ------time------
# [2017, 6, 2, 9, 49]
#
# ------bandlist------
# ['u10_time2443', 'v10_time2443']
# --------success-----
# ------time------
# [2017, 6, 1, 23, 20]
#
# ------bandlist------
# ['u10_time2441', 'v10_time2441']
# --------success-----
#
# ------time------
# [2017, 6, 1, 23, 20]
#
# ------bandlist------
# ['u10_time2441', 'v10_time2441']
# --------success-----
#
# ------time------
# [2017, 5, 31, 23, 33]
#
# ------bandlist------
# ['u10_time2437', 'v10_time2437']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 31, 23, 33]
#
# ------bandlist------
# ['u10_time2437', 'v10_time2437']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 31, 23, 32]
#
# ------bandlist------
# ['u10_time2437', 'v10_time2437']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 31, 23, 32]
#
# ------bandlist------
# ['u10_time2437', 'v10_time2437']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 31, 23, 31]
#
# ------bandlist------
# ['u10_time2437', 'v10_time2437']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 31, 22, 43]
#
# ------bandlist------
# ['u10_time2437', 'v10_time2437']
# --------success-----
#
# ------time------
# [2017, 5, 31, 22, 43]
#
# ------bandlist------
# ['u10_time2437', 'v10_time2437']
# --------success-----
#
# ------time------
# [2017, 5, 31, 22, 42]
#
# ------bandlist------
# ['u10_time2437', 'v10_time2437']
# --------success-----
#
# ------time------
# [2017, 5, 31, 22, 42]
#
# ------bandlist------
# ['u10_time2437', 'v10_time2437']
# --------success-----
#
# ------time------
# [2017, 5, 31, 22, 41]
#
# ------bandlist------
# ['u10_time2437', 'v10_time2437']
# --------success-----
#
# ------time------
# [2017, 5, 31, 10, 47]
#
# ------bandlist------
# ['u10_time2435', 'v10_time2435']
# --------success-----
#
# ------time------
# [2017, 5, 31, 10, 5]
#
# ------bandlist------
# ['u10_time2435', 'v10_time2435']
# --------success-----
#
# ------time------
# [2017, 5, 31, 10, 5]
#
# ------bandlist------
# ['u10_time2435', 'v10_time2435']
# --------success-----
#
# ------time------
# [2017, 5, 31, 3, 51]
#
# ------bandlist------
# ['u10_time2434', 'v10_time2434']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 31, 3, 51]
#
# ------bandlist------
# ['u10_time2434', 'v10_time2434']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 31, 3, 50]
#
# ------bandlist------
# ['u10_time2434', 'v10_time2434']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 31, 2, 9]
#
# ------bandlist------
# ['u10_time2433', 'v10_time2433']
# --------success-----
#
# ------time------
# [2017, 5, 31, 2, 9]
#
# ------bandlist------
# ['u10_time2433', 'v10_time2433']
# --------success-----
#
# ------time------
# [2017, 5, 31, 2, 8]
#
# ------bandlist------
# ['u10_time2433', 'v10_time2433']
# --------success-----
#
# ------time------
# [2017, 5, 31, 2, 8]
#
# ------bandlist------
# ['u10_time2433', 'v10_time2433']
# --------success-----
#
# ------time------
# [2017, 5, 31, 2, 7]
#
# ------bandlist------
# ['u10_time2433', 'v10_time2433']
# --------success-----
#
# ------time------
# [2017, 5, 31, 2, 7]
#
# ------bandlist------
# ['u10_time2433', 'v10_time2433']
# --------success-----
#
# ------time------
# [2017, 5, 31, 2, 6]
#
# ------bandlist------
# ['u10_time2433', 'v10_time2433']
# --------success-----
#
# ------time------
# [2017, 5, 31, 2, 6]
#
# ------bandlist------
# ['u10_time2433', 'v10_time2433']
# --------success-----
#
# ------time------
# [2017, 5, 31, 2, 6]
#
# ------bandlist------
# ['u10_time2433', 'v10_time2433']
# --------success-----
#
# ------time------
# [2017, 5, 31, 2, 5]
#
# ------bandlist------
# ['u10_time2433', 'v10_time2433']
# --------success-----
#
# ------time------
# [2017, 5, 31, 2, 5]
#
# ------bandlist------
# ['u10_time2433', 'v10_time2433']
# --------success-----
#
# ------time------
# [2017, 5, 30, 23, 42]
#
# ------bandlist------
# ['u10_time2433', 'v10_time2433']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 30, 23, 41]
#
# ------bandlist------
# ['u10_time2433', 'v10_time2433']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 30, 23, 41]
#
# ------bandlist------
# ['u10_time2433', 'v10_time2433']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 30, 23, 37]
#
# ------bandlist------
# ['u10_time2433', 'v10_time2433']
# --------success-----
#
# ------time------
# [2017, 5, 30, 23, 36]
#
# ------bandlist------
# ['u10_time2433', 'v10_time2433']
# --------success-----
#
# ------time------
# [2017, 5, 30, 23, 36]
#
# ------bandlist------
# ['u10_time2433', 'v10_time2433']
# --------success-----
#
# ------time------
# [2017, 5, 30, 23, 35]
#
# ------bandlist------
# ['u10_time2433', 'v10_time2433']
# --------success-----
#
# ------time------
# [2017, 5, 30, 16, 0]
#
# ------bandlist------
# ['u10_time2432', 'v10_time2432']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 30, 15, 59]
#
# ------bandlist------
# ['u10_time2432', 'v10_time2432']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 30, 14, 16]
#
# ------bandlist------
# ['u10_time2431', 'v10_time2431']
# --------success-----
#
# ------time------
# [2017, 5, 30, 14, 15]
#
# ------bandlist------
# ['u10_time2431', 'v10_time2431']
# --------success-----
#
# ------time------
# [2017, 5, 30, 14, 15]
#
# ------bandlist------
# ['u10_time2431', 'v10_time2431']
# --------success-----
#
# ------time------
# [2017, 5, 30, 14, 15]
#
# ------bandlist------
# ['u10_time2431', 'v10_time2431']
# --------success-----
#
# ------time------
# [2017, 5, 30, 4, 37]
#
# ------bandlist------
# ['u10_time2430', 'v10_time2430']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 30, 4, 37]
#
# ------bandlist------
# ['u10_time2430', 'v10_time2430']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 30, 0, 34]
#
# ------bandlist------
# ['u10_time2429', 'v10_time2429']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 30, 0, 33]
#
# ------bandlist------
# ['u10_time2429', 'v10_time2429']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 30, 0, 32]
#
# ------bandlist------
# ['u10_time2429', 'v10_time2429']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 30, 0, 31]
#
# ------bandlist------
# ['u10_time2429', 'v10_time2429']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 29, 23, 49]
#
# ------bandlist------
# ['u10_time2429', 'v10_time2429']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 29, 23, 0]
#
# ------bandlist------
# ['u10_time2429', 'v10_time2429']
# --------success-----
#
# ------time------
# [2017, 5, 29, 22, 59]
#
# ------bandlist------
# ['u10_time2429', 'v10_time2429']
# --------success-----
#
# ------time------
# [2017, 5, 29, 22, 58]
#
# ------bandlist------
# ['u10_time2429', 'v10_time2429']
# --------success-----
#
# ------time------
# [2017, 5, 29, 22, 57]
#
# ------bandlist------
# ['u10_time2429', 'v10_time2429']
# --------success-----
#
# ------time------
# [2017, 5, 29, 22, 53]
#
# ------bandlist------
# ['u10_time2429', 'v10_time2429']
# --------success-----
#
# ------time------
# [2017, 5, 29, 10, 21]
#
# ------bandlist------
# ['u10_time2427', 'v10_time2427']
# --------success-----
#
# ------time------
# [2017, 5, 29, 5, 44]
#
# ------bandlist------
# ['u10_time2426', 'v10_time2426']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 29, 4, 48]
#
# ------bandlist------
# ['u10_time2426', 'v10_time2426']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 29, 4, 47]
#
# ------bandlist------
# ['u10_time2426', 'v10_time2426']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 29, 4, 46]
#
# ------bandlist------
# ['u10_time2426', 'v10_time2426']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 28, 23, 53]
#
# ------bandlist------
# ['u10_time2425', 'v10_time2425']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 28, 23, 53]
#
# ------bandlist------
# ['u10_time2425', 'v10_time2425']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 28, 11, 18]
#
# ------bandlist------
# ['u10_time2423', 'v10_time2423']
# --------success-----
#
# ------time------
# [2017, 5, 28, 5, 53]
#
# ------bandlist------
# ['u10_time2422', 'v10_time2422']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 28, 5, 4]
#
# ------bandlist------
# ['u10_time2422', 'v10_time2422']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 28, 4, 55]
#
# ------bandlist------
# ['u10_time2422', 'v10_time2422']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 28, 4, 55]
#
# ------bandlist------
# ['u10_time2422', 'v10_time2422']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 28, 4, 54]
#
# ------bandlist------
# ['u10_time2422', 'v10_time2422']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 28, 4, 54]
#
# ------bandlist------
# ['u10_time2422', 'v10_time2422']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 28, 2, 37]
#
# ------bandlist------
# ['u10_time2421', 'v10_time2421']
# --------success-----
#
# ------time------
# [2017, 5, 28, 2, 37]
#
# ------bandlist------
# ['u10_time2421', 'v10_time2421']
# --------success-----
#
# ------time------
# [2017, 5, 27, 23, 16]
#
# ------bandlist------
# ['u10_time2421', 'v10_time2421']
# --------success-----
#
# ------time------
# [2017, 5, 27, 23, 11]
#
# ------bandlist------
# ['u10_time2421', 'v10_time2421']
# --------success-----
#
# ------time------
# [2017, 5, 27, 22, 26]
#
# ------bandlist------
# ['u10_time2421', 'v10_time2421']
# --------success-----
#
# ------time------
# [2017, 5, 27, 22, 25]
#
# ------bandlist------
# ['u10_time2421', 'v10_time2421']
# --------success-----
#
# ------time------
# [2017, 5, 27, 22, 25]
#
# ------bandlist------
# ['u10_time2421', 'v10_time2421']
# --------success-----
#
# ------time------
# [2017, 5, 27, 12, 17]
#
# ------bandlist------
# ['u10_time2419', 'v10_time2419']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 26, 23, 24]
#
# ------bandlist------
# ['u10_time2417', 'v10_time2417']
# --------success-----
#
# ------time------
# [2017, 5, 26, 22, 35]
#
# ------bandlist------
# ['u10_time2417', 'v10_time2417']
# --------success-----
#
# ------time------
# [2017, 5, 26, 22, 35]
#
# ------bandlist------
# ['u10_time2417', 'v10_time2417']
# --------success-----
#
# ------time------
# [2017, 5, 26, 22, 34]
#
# ------bandlist------
# ['u10_time2417', 'v10_time2417']
# --------success-----
#
# ------time------
# [2017, 5, 26, 22, 29]
#
# ------bandlist------
# ['u10_time2417', 'v10_time2417']
# --------success-----
#
# ------time------
# [2017, 5, 26, 22, 28]
#
# ------bandlist------
# ['u10_time2417', 'v10_time2417']
# --------success-----
#
# ------time------
# [2017, 5, 26, 16, 32]
#
# ------bandlist------
# ['u10_time2416', 'v10_time2416']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 26, 12, 25]
#
# ------bandlist------
# ['u10_time2415', 'v10_time2415']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 26, 12, 22]
#
# ------bandlist------
# ['u10_time2415', 'v10_time2415']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 26, 9, 57]
#
# ------bandlist------
# ['u10_time2415', 'v10_time2415']
# --------success-----
#
# ------time------
# [2017, 5, 26, 9, 57]
#
# ------bandlist------
# ['u10_time2415', 'v10_time2415']
# --------success-----
#
# ------time------
# [2017, 5, 26, 4, 23]
#
# ------bandlist------
# ['u10_time2414', 'v10_time2414']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 26, 4, 22]
#
# ------bandlist------
# ['u10_time2414', 'v10_time2414']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 26, 4, 21]
#
# ------bandlist------
# ['u10_time2414', 'v10_time2414']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 26, 2, 54]
#
# ------bandlist------
# ['u10_time2413', 'v10_time2413']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 26, 2, 54]
#
# ------bandlist------
# ['u10_time2413', 'v10_time2413']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 26, 2, 53]
#
# ------bandlist------
# ['u10_time2413', 'v10_time2413']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 26, 2, 1]
#
# ------bandlist------
# ['u10_time2413', 'v10_time2413']
# --------success-----
#
# ------time------
# [2017, 5, 26, 2, 0]
#
# ------bandlist------
# ['u10_time2413', 'v10_time2413']
# --------success-----
#
# ------time------
# [2017, 5, 26, 1, 57]
#
# ------bandlist------
# ['u10_time2413', 'v10_time2413']
# --------success-----
#
# ------time------
# [2017, 5, 26, 1, 57]
#
# ------bandlist------
# ['u10_time2413', 'v10_time2413']
# --------success-----
#
# ------time------
# [2017, 5, 26, 1, 57]
#
# ------bandlist------
# ['u10_time2413', 'v10_time2413']
# --------success-----
#
# ------time------
# [2017, 5, 25, 23, 31]
#
# ------bandlist------
# ['u10_time2413', 'v10_time2413']
# --------success-----
#
# ------time------
# [2017, 5, 25, 23, 28]
#
# ------bandlist------
# ['u10_time2413', 'v10_time2413']
# --------success-----
#
# ------time------
# [2017, 5, 25, 23, 28]
#
# ------bandlist------
# ['u10_time2413', 'v10_time2413']
# --------success-----
#
# ------time------
# [2017, 5, 25, 23, 28]
#
# ------bandlist------
# ['u10_time2413', 'v10_time2413']
# --------success-----
#
# ------time------
# [2017, 5, 25, 23, 27]
#
# ------bandlist------
# ['u10_time2413', 'v10_time2413']
# --------success-----
#
# ------time------
# [2017, 5, 25, 23, 27]
#
# ------bandlist------
# ['u10_time2413', 'v10_time2413']
# --------success-----
#
# ------time------
# [2017, 5, 25, 14, 7]
#
# ------bandlist------
# ['u10_time2411', 'v10_time2411']
# --------success-----
#
# ------time------
# [2017, 5, 25, 12, 31]
#
# ------bandlist------
# ['u10_time2411', 'v10_time2411']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 25, 0, 26]
#
# ------bandlist------
# ['u10_time2409', 'v10_time2409']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 25, 0, 26]
#
# ------bandlist------
# ['u10_time2409', 'v10_time2409']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 24, 22, 45]
#
# ------bandlist------
# ['u10_time2409', 'v10_time2409']
# --------success-----
#
# ------time------
# [2017, 5, 24, 22, 45]
#
# ------bandlist------
# ['u10_time2409', 'v10_time2409']
# --------success-----
#
# ------time------
# [2017, 5, 24, 18, 18]
#
# ------bandlist------
# ['u10_time2408', 'v10_time2408']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 24, 15, 59]
#
# ------bandlist------
# ['u10_time2408', 'v10_time2408']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 24, 15, 59]
#
# ------bandlist------
# ['u10_time2408', 'v10_time2408']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 24, 5, 36]
#
# ------bandlist------
# ['u10_time2406', 'v10_time2406']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 24, 4, 38]
#
# ------bandlist------
# ['u10_time2406', 'v10_time2406']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 24, 4, 38]
#
# ------bandlist------
# ['u10_time2406', 'v10_time2406']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 24, 2, 17]
#
# ------bandlist------
# ['u10_time2405', 'v10_time2405']
# --------success-----
#
# ------time------
# [2017, 5, 24, 2, 16]
#
# ------bandlist------
# ['u10_time2405', 'v10_time2405']
# --------success-----
#
# ------time------
# [2017, 5, 24, 2, 16]
#
# ------bandlist------
# ['u10_time2405', 'v10_time2405']
# --------success-----
#
# ------time------
# [2017, 5, 24, 2, 16]
#
# ------bandlist------
# ['u10_time2405', 'v10_time2405']
# --------success-----
#
# ------time------
# [2017, 5, 24, 2, 15]
#
# ------bandlist------
# ['u10_time2405', 'v10_time2405']
# --------success-----
#
# ------time------
# [2017, 5, 24, 2, 15]
#
# ------bandlist------
# ['u10_time2405', 'v10_time2405']
# --------success-----
#
# ------time------
# [2017, 5, 24, 2, 14]
#
# ------bandlist------
# ['u10_time2405', 'v10_time2405']
# --------success-----
#
# ------time------
# [2017, 5, 24, 2, 14]
#
# ------bandlist------
# ['u10_time2405', 'v10_time2405']
# --------success-----
#
# ------time------
# [2017, 5, 23, 22, 59]
#
# ------bandlist------
# ['u10_time2405', 'v10_time2405']
# --------success-----
#
# ------time------
# [2017, 5, 23, 22, 58]
#
# ------bandlist------
# ['u10_time2405', 'v10_time2405']
# --------success-----
#
# ------time------
# [2017, 5, 23, 22, 3]
#
# ------bandlist------
# ['u10_time2405', 'v10_time2405']
# --------success-----
#
# ------time------
# [2017, 5, 23, 22, 3]
#
# ------bandlist------
# ['u10_time2405', 'v10_time2405']
# --------success-----
#
# ------time------
# [2017, 5, 23, 22, 3]
#
# ------bandlist------
# ['u10_time2405', 'v10_time2405']
# --------success-----
#
# ------time------
# [2017, 5, 23, 14, 24]
#
# ------bandlist------
# ['u10_time2403', 'v10_time2403']
# --------success-----
#
# ------time------
# [2017, 5, 23, 14, 23]
#
# ------bandlist------
# ['u10_time2403', 'v10_time2403']
# --------success-----
#
# ------time------
# [2017, 5, 23, 14, 23]
#
# ------bandlist------
# ['u10_time2403', 'v10_time2403']
# --------success-----
#
# ------time------
# [2017, 5, 23, 14, 22]
#
# ------bandlist------
# ['u10_time2403', 'v10_time2403']
# --------success-----
#
# ------time------
# [2017, 5, 23, 14, 22]
#
# ------bandlist------
# ['u10_time2403', 'v10_time2403']
# --------success-----
#
# ------time------
# [2017, 5, 23, 14, 21]
#
# ------bandlist------
# ['u10_time2403', 'v10_time2403']
# --------success-----
#
# ------time------
# [2017, 5, 23, 11, 9]
#
# ------bandlist------
# ['u10_time2403', 'v10_time2403']
# --------success-----
#
# ------time------
# [2017, 5, 23, 4, 47]
#
# ------bandlist------
# ['u10_time2402', 'v10_time2402']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 23, 4, 46]
#
# ------bandlist------
# ['u10_time2402', 'v10_time2402']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 23, 4, 45]
#
# ------bandlist------
# ['u10_time2402', 'v10_time2402']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 23, 3, 19]
#
# ------bandlist------
# ['u10_time2402', 'v10_time2402']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 23, 3, 18]
#
# ------bandlist------
# ['u10_time2402', 'v10_time2402']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 23, 0, 40]
#
# ------bandlist------
# ['u10_time2401', 'v10_time2401']
# exception
# --------success-----
# ------time------
# [2017, 5, 22, 23, 8]
#
# ------bandlist------
# ['u10_time2401', 'v10_time2401']
# --------success-----
#
# ------time------
# [2017, 5, 22, 23, 7]
#
# ------bandlist------
# ['u10_time2401', 'v10_time2401']
# --------success-----
#
# ------time------
# [2017, 5, 22, 23, 6]
#
# ------bandlist------
# ['u10_time2401', 'v10_time2401']
# --------success-----
#
# ------time------
# [2017, 5, 22, 23, 5]
#
# ------bandlist------
# ['u10_time2401', 'v10_time2401']
# --------success-----
#
# ------time------
# [2017, 5, 22, 23, 5]
#
# ------bandlist------
# ['u10_time2401', 'v10_time2401']
# --------success-----
#
# ------time------
# [2017, 5, 22, 23, 4]
#
# ------bandlist------
# ['u10_time2401', 'v10_time2401']
# --------success-----
#
# ------time------
# [2017, 5, 22, 23, 4]
#
# ------bandlist------
# ['u10_time2401', 'v10_time2401']
# --------success-----
#
# ------time------
# [2017, 5, 22, 23, 4]
#
# ------bandlist------
# ['u10_time2401', 'v10_time2401']
# --------success-----
#
# ------time------
# [2017, 5, 22, 23, 3]
#
# ------bandlist------
# ['u10_time2401', 'v10_time2401']
# --------success-----
#
# ------time------
# [2017, 5, 22, 23, 3]
#
# ------bandlist------
# ['u10_time2401', 'v10_time2401']
# --------success-----
#
# ------time------
# [2017, 5, 22, 23, 2]
#
# ------bandlist------
# ['u10_time2401', 'v10_time2401']
# --------success-----
#
# ------time------
# [2017, 5, 22, 16, 15]
#
# ------bandlist------
# ['u10_time2400', 'v10_time2400']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 22, 16, 14]
#
# ------bandlist------
# ['u10_time2400', 'v10_time2400']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 22, 16, 14]
#
# ------bandlist------
# ['u10_time2400', 'v10_time2400']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 22, 14, 30]
#
# ------bandlist------
# ['u10_time2399', 'v10_time2399']
# --------success-----
#
# ------time------
# [2017, 5, 22, 14, 29]
#
# ------bandlist------
# ['u10_time2399', 'v10_time2399']
# --------success-----
#
# ------time------
# [2017, 5, 22, 14, 29]
#
# ------bandlist------
# ['u10_time2399', 'v10_time2399']
# --------success-----
#
# ------time------
# [2017, 5, 22, 14, 28]
#
# ------bandlist------
# ['u10_time2399', 'v10_time2399']
# --------success-----
#
# ------time------
# [2017, 5, 22, 4, 56]
#
# ------bandlist------
# ['u10_time2398', 'v10_time2398']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 22, 4, 56]
#
# ------bandlist------
# ['u10_time2398', 'v10_time2398']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 22, 4, 55]
#
# ------bandlist------
# ['u10_time2398', 'v10_time2398']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 22, 4, 54]
#
# ------bandlist------
# ['u10_time2398', 'v10_time2398']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 22, 0, 1]
#
# ------bandlist------
# ['u10_time2397', 'v10_time2397']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 21, 23, 16]
#
# ------bandlist------
# ['u10_time2397', 'v10_time2397']
# --------success-----
#
# ------time------
# [2017, 5, 21, 23, 15]
#
# ------bandlist------
# ['u10_time2397', 'v10_time2397']
# --------success-----
#
# ------time------
# [2017, 5, 21, 22, 20]
#
# ------bandlist------
# ['u10_time2397', 'v10_time2397']
# --------success-----
#
# ------time------
# [2017, 5, 21, 22, 20]
#
# ------bandlist------
# ['u10_time2397', 'v10_time2397']
# --------success-----
#
# ------time------
# [2017, 5, 21, 9, 49]
#
# ------bandlist------
# ['u10_time2395', 'v10_time2395']
# --------success-----
#
# ------time------
# [2017, 5, 21, 9, 49]
#
# ------bandlist------
# ['u10_time2395', 'v10_time2395']
# --------success-----
#
# ------time------
# [2017, 5, 21, 5, 11]
#
# ------bandlist------
# ['u10_time2394', 'v10_time2394']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 21, 3, 35]
#
# ------bandlist------
# ['u10_time2394', 'v10_time2394']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 21, 1, 53]
#
# ------bandlist------
# ['u10_time2393', 'v10_time2393']
# --------success-----
#
# ------time------
# [2017, 5, 21, 1, 48]
#
# ------bandlist------
# ['u10_time2393', 'v10_time2393']
# --------success-----
#
# ------time------
# [2017, 5, 21, 1, 48]
#
# ------bandlist------
# ['u10_time2393', 'v10_time2393']
# --------success-----
#
# ------time------
# [2017, 5, 20, 23, 24]
#
# ------bandlist------
# ['u10_time2393', 'v10_time2393']
# --------success-----
#
# ------time------
# [2017, 5, 20, 23, 24]
#
# ------bandlist------
# ['u10_time2393', 'v10_time2393']
# --------success-----
#
# ------time------
# [2017, 5, 20, 23, 23]
#
# ------bandlist------
# ['u10_time2393', 'v10_time2393']
# --------success-----
#
# ------time------
# [2017, 5, 20, 23, 23]
#
# ------bandlist------
# ['u10_time2393', 'v10_time2393']
# --------success-----
#
# ------time------
# [2017, 5, 20, 23, 20]
#
# ------bandlist------
# ['u10_time2393', 'v10_time2393']
# --------success-----
#
# ------time------
# [2017, 5, 20, 23, 20]
#
# ------bandlist------
# ['u10_time2393', 'v10_time2393']
# --------success-----
#
# ------time------
# [2017, 5, 20, 23, 19]
#
# ------bandlist------
# ['u10_time2393', 'v10_time2393']
# --------success-----
#
# ------time------
# [2017, 5, 20, 23, 19]
#
# ------bandlist------
# ['u10_time2393', 'v10_time2393']
# --------success-----
#
# ------time------
# [2017, 5, 20, 16, 31]
#
# ------bandlist------
# ['u10_time2392', 'v10_time2392']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 20, 14, 1]
#
# ------bandlist------
# ['u10_time2391', 'v10_time2391']
# --------success-----
#
# ------time------
# [2017, 5, 20, 14, 0]
#
# ------bandlist------
# ['u10_time2391', 'v10_time2391']
# --------success-----
#
# ------time------
# [2017, 5, 20, 14, 0]
#
# ------bandlist------
# ['u10_time2391', 'v10_time2391']
# --------success-----
#
# ------time------
# [2017, 5, 20, 12, 25]
#
# ------bandlist------
# ['u10_time2391', 'v10_time2391']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 20, 12, 23]
#
# ------bandlist------
# ['u10_time2391', 'v10_time2391']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 20, 12, 22]
#
# ------bandlist------
# ['u10_time2391', 'v10_time2391']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 20, 4, 22]
#
# ------bandlist------
# ['u10_time2390', 'v10_time2390']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 20, 4, 22]
#
# ------bandlist------
# ['u10_time2390', 'v10_time2390']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 20, 4, 20]
#
# ------bandlist------
# ['u10_time2390', 'v10_time2390']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 20, 0, 18]
#
# ------bandlist------
# ['u10_time2389', 'v10_time2389']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 20, 0, 17]
#
# ------bandlist------
# ['u10_time2389', 'v10_time2389']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 19, 23, 33]
#
# ------bandlist------
# ['u10_time2389', 'v10_time2389']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 19, 23, 33]
#
# ------bandlist------
# ['u10_time2389', 'v10_time2389']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 19, 23, 32]
#
# ------bandlist------
# ['u10_time2389', 'v10_time2389']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 19, 23, 32]
#
# ------bandlist------
# ['u10_time2389', 'v10_time2389']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 19, 23, 31]
#
# ------bandlist------
# ['u10_time2389', 'v10_time2389']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 19, 22, 43]
#
# ------bandlist------
# ['u10_time2389', 'v10_time2389']
# --------success-----
#
# ------time------
# [2017, 5, 19, 22, 43]
#
# ------bandlist------
# ['u10_time2389', 'v10_time2389']
# --------success-----
#
# ------time------
# [2017, 5, 19, 22, 42]
#
# ------bandlist------
# ['u10_time2389', 'v10_time2389']
# --------success-----
#
# ------time------
# [2017, 5, 19, 22, 42]
#
# ------bandlist------
# ['u10_time2389', 'v10_time2389']
# --------success-----
#
# ------time------
# [2017, 5, 19, 22, 41]
#
# ------bandlist------
# ['u10_time2389', 'v10_time2389']
# --------success-----
#
# ------time------
# [2017, 5, 19, 22, 41]
#
# ------bandlist------
# ['u10_time2389', 'v10_time2389']
# --------success-----
#
# ------time------
# [2017, 5, 19, 10, 48]
#
# ------bandlist------
# ['u10_time2387', 'v10_time2387']
# --------success-----
#
# ------time------
# [2017, 5, 19, 10, 48]
#
# ------bandlist------
# ['u10_time2387', 'v10_time2387']
# --------success-----
#
# ------time------
# [2017, 5, 19, 10, 47]
#
# ------bandlist------
# ['u10_time2387', 'v10_time2387']
# --------success-----
#
# ------time------
# [2017, 5, 19, 10, 5]
#
# ------bandlist------
# ['u10_time2387', 'v10_time2387']
# --------success-----
# ------time------
# [2017, 5, 19, 3, 51]
#
# ------bandlist------
# ['u10_time2386', 'v10_time2386']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 19, 3, 51]
#
# ------bandlist------
# ['u10_time2386', 'v10_time2386']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 19, 3, 50]
#
# ------bandlist------
# ['u10_time2386', 'v10_time2386']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 19, 2, 9]
#
# ------bandlist------
# ['u10_time2385', 'v10_time2385']
# --------success-----
#
# ------time------
# [2017, 5, 19, 2, 9]
#
# ------bandlist------
# ['u10_time2385', 'v10_time2385']
# --------success-----
#
# ------time------
# [2017, 5, 19, 2, 8]
#
# ------bandlist------
# ['u10_time2385', 'v10_time2385']
# --------success-----
#
# ------time------
# [2017, 5, 19, 2, 8]
#
# ------bandlist------
# ['u10_time2385', 'v10_time2385']
# --------success-----
#
# ------time------
# [2017, 5, 19, 2, 7]
#
# ------bandlist------
# ['u10_time2385', 'v10_time2385']
# --------success-----
#
# ------time------
# [2017, 5, 19, 2, 7]
#
# ------bandlist------
# ['u10_time2385', 'v10_time2385']
# --------success-----
#
# ------time------
# [2017, 5, 19, 2, 6]
#
# ------bandlist------
# ['u10_time2385', 'v10_time2385']
# --------success-----
#
# ------time------
# [2017, 5, 19, 2, 6]
#
# ------bandlist------
# ['u10_time2385', 'v10_time2385']
# --------success-----
#
# ------time------
# [2017, 5, 19, 2, 6]
#
# ------bandlist------
# ['u10_time2385', 'v10_time2385']
# --------success-----
#
# ------time------
# [2017, 5, 19, 2, 5]
#
# ------bandlist------
# ['u10_time2385', 'v10_time2385']
# --------success-----
#
# ------time------
# [2017, 5, 19, 2, 5]
#
# ------bandlist------
# ['u10_time2385', 'v10_time2385']
# --------success-----
#
# ------time------
# [2017, 5, 18, 23, 37]
#
# ------bandlist------
# ['u10_time2385', 'v10_time2385']
# --------success-----
#
# ------time------
# [2017, 5, 18, 23, 36]
#
# ------bandlist------
# ['u10_time2385', 'v10_time2385']
# --------success-----
#
# ------time------
# [2017, 5, 18, 23, 36]
#
# ------bandlist------
# ['u10_time2385', 'v10_time2385']
# --------success-----
#
# ------time------
# [2017, 5, 18, 23, 35]
#
# ------bandlist------
# ['u10_time2385', 'v10_time2385']
# --------success-----
#
# ------time------
# [2017, 5, 18, 14, 16]
#
# ------bandlist------
# ['u10_time2383', 'v10_time2383']
# --------success-----
#
# ------time------
# [2017, 5, 18, 14, 15]
#
# ------bandlist------
# ['u10_time2383', 'v10_time2383']
# --------success-----
#
# ------time------
# [2017, 5, 18, 14, 15]
#
# ------bandlist------
# ['u10_time2383', 'v10_time2383']
# --------success-----
#
# ------time------
# [2017, 5, 18, 4, 37]
#
# ------bandlist------
# ['u10_time2382', 'v10_time2382']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 18, 4, 37]
#
# ------bandlist------
# ['u10_time2382', 'v10_time2382']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 18, 0, 34]
#
# ------bandlist------
# ['u10_time2381', 'v10_time2381']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 18, 0, 33]
#
# ------bandlist------
# ['u10_time2381', 'v10_time2381']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 18, 0, 32]
#
# ------bandlist------
# ['u10_time2381', 'v10_time2381']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 18, 0, 31]
#
# ------bandlist------
# ['u10_time2381', 'v10_time2381']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 17, 23, 49]
#
# ------bandlist------
# ['u10_time2381', 'v10_time2381']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 17, 23, 0]
#
# ------bandlist------
# ['u10_time2381', 'v10_time2381']
# --------success-----
#
# ------time------
# [2017, 5, 17, 22, 59]
#
# ------bandlist------
# ['u10_time2381', 'v10_time2381']
# --------success-----
#
# ------time------
# [2017, 5, 17, 22, 58]
#
# ------bandlist------
# ['u10_time2381', 'v10_time2381']
# --------success-----
#
# ------time------
# [2017, 5, 17, 22, 57]
#
# ------bandlist------
# ['u10_time2381', 'v10_time2381']
# --------success-----
#
# ------time------
# [2017, 5, 17, 22, 53]
#
# ------bandlist------
# ['u10_time2381', 'v10_time2381']
# --------success-----
#
# ------time------
# [2017, 5, 17, 10, 21]
#
# ------bandlist------
# ['u10_time2379', 'v10_time2379']
# --------success-----
#
# ------time------
# [2017, 5, 17, 10, 21]
#
# ------bandlist------
# ['u10_time2379', 'v10_time2379']
# --------success-----
#
# ------time------
# [2017, 5, 17, 5, 44]
#
# ------bandlist------
# ['u10_time2378', 'v10_time2378']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 17, 4, 48]
#
# ------bandlist------
# ['u10_time2378', 'v10_time2378']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 17, 2, 28]
#
# ------bandlist------
# ['u10_time2377', 'v10_time2377']
# --------success-----
#
# ------time------
# [2017, 5, 16, 23, 53]
#
# ------bandlist------
# ['u10_time2377', 'v10_time2377']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 16, 23, 53]
#
# ------bandlist------
# ['u10_time2377', 'v10_time2377']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 16, 16, 14]
#
# ------bandlist------
# ['u10_time2376', 'v10_time2376']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 16, 11, 18]
#
# ------bandlist------
# ['u10_time2375', 'v10_time2375']
# --------success-----
#
# ------time------
# [2017, 5, 16, 9, 41]
#
# ------bandlist------
# ['u10_time2375', 'v10_time2375']
# --------success-----
#
# ------time------
# [2017, 5, 16, 5, 53]
#
# ------bandlist------
# ['u10_time2374', 'v10_time2374']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 16, 5, 4]
#
# ------bandlist------
# ['u10_time2374', 'v10_time2374']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 16, 4, 55]
#
# ------bandlist------
# ['u10_time2374', 'v10_time2374']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 16, 4, 55]
#
# ------bandlist------
# ['u10_time2374', 'v10_time2374']
# exception
# --------success-----
#
# ------time------
# [2017, 5, 16, 2, 37]
#
# ------bandlist------
# ['u10_time2373', 'v10_time2373']
# --------success-----
#
# ------time------
# [2017, 5, 16, 2, 37]
#
# ------bandlist------
# ['u10_time2373', 'v10_time2373']
# --------success-----
#
# ------time------
# [2017, 5, 15, 23, 16]
#
# ------bandlist------
# ['u10_time2373', 'v10_time2373']
# --------success-----
#
# ------time------
# [2017, 5, 15, 23, 13]
#
# ------bandlist------
# ['u10_time2373', 'v10_time2373']
# --------success-----
#
# ------time------
# ...
# ['u10_time2293', 'v10_time2293']
# --------success-----
#
# ------time------
# [2017, 4, 25, 10, 48]
#
# ------bandlist------
# ['u10_time2291', 'v10_time2291']
# --------success-----
#
# ------time------
# [2017, 4, 25, 10, 48]
#
# ------bandlist------
# ['u10_time2291', 'v10_time2291']
# --------success-----
#
# ------time------
# [2017, 4, 25, 10, 5]
#
# ------bandlist------
# ['u10_time2291', 'v10_time2291']
# --------success-----
#
# ------time------
# [2017, 4, 25, 10, 5]
#
# ------bandlist------
# ['u10_time2291', 'v10_time2291']
# --------success-----
#
# ------time------
# [2017, 4, 25, 3, 51]
#
# ------bandlist------
# ['u10_time2290', 'v10_time2290']
# exception
# --------success-----
#
# ------time------
# [2017, 4, 25, 3, 51]
#
# ------bandlist------
# ['u10_time2290', 'v10_time2290']
# exception
# --------success-----
#
# ------time------
# [2017, 4, 25, 3, 50]
#
# ------bandlist------
# ['u10_time2290', 'v10_time2290']
# exception
# --------success-----
#
# ------time------
# [2017, 4, 24, 23, 37]
#
# ------bandlist------
# ['u10_time2289', 'v10_time2289']
# --------success-----
#
# ------time------
# [2017, 4, 24, 23, 36]
#
# ------bandlist------
# ['u10_time2289', 'v10_time2289']
# --------success-----
#
# ------time------
# [2017, 4, 24, 23, 36]
#
# ------bandlist------
# ['u10_time2289', 'v10_time2289']
# --------success-----
#
# ------time------
# [2017, 4, 24, 23, 35]
#
# ------bandlist------
# ['u10_time2289', 'v10_time2289']
# --------success-----
#
# ------time------
# [2017, 4, 23, 22, 53]
#
# ------bandlist------
# ['u10_time2285', 'v10_time2285']
# --------success-----
#
# ------time------
# [2017, 4, 23, 10, 21]
#
# ------bandlist------
# ['u10_time2283', 'v10_time2283']
# --------success-----
#
# ------time------
# [2017, 4, 23, 10, 21]
#
# ------bandlist------
# ['u10_time2283', 'v10_time2283']
# --------success-----
#
# ------time------
# [2017, 4, 23, 2, 28]
#
# ------bandlist------
# ['u10_time2281', 'v10_time2281']
# --------success-----
#
# ------time------
# [2017, 4, 22, 11, 18]
#
# ------bandlist------
# ['u10_time2279', 'v10_time2279']
# --------success-----
#
# ------time------
# [2017, 4, 22, 9, 41]
#
# ------bandlist------
# ['u10_time2279', 'v10_time2279']
# --------success-----
#
# ------time------
# [2017, 4, 22, 5, 4]
#
# ------bandlist------
# ['u10_time2278', 'v10_time2278']
# exception
# --------success-----
#
# ------time------
# [2017, 4, 22, 2, 37]
#
# ------bandlist------
# ['u10_time2277', 'v10_time2277']
# --------success-----
#
# ------time------
# [2017, 4, 22, 2, 37]
#
# ------bandlist------
# ['u10_time2277', 'v10_time2277']
# --------success-----
#
# ------time------
# [2017, 4, 21, 23, 13]
#
# ------bandlist------
# ['u10_time2277', 'v10_time2277']
# --------success-----
#
# ------time------
# [2017, 4, 21, 23, 12]
#
# ------bandlist------
# ['u10_time2277', 'v10_time2277']
# --------success-----
#
# ------time------
# [2017, 4, 21, 23, 12]
#
# ------bandlist------
# ['u10_time2277', 'v10_time2277']
# --------success-----
#
# ------time------
# [2017, 4, 21, 23, 11]
#
# ------bandlist------
# ['u10_time2277', 'v10_time2277']
# --------success-----
#
# ------time------
# [2017, 4, 21, 23, 11]
#
# ------bandlist------
# ['u10_time2277', 'v10_time2277']
# --------success-----
#
# ------time------
# [2017, 4, 21, 22, 25]
#
# ------bandlist------
# ['u10_time2277', 'v10_time2277']
# --------success-----
#
# ------time------
# [2017, 4, 21, 22, 25]
#
# ------bandlist------
# ['u10_time2277', 'v10_time2277']
# --------success-----
#
# ------time------
# [2017, 4, 20, 22, 34]
#
# ------bandlist------
# ['u10_time2273', 'v10_time2273']
# --------success-----
#
# ------time------
# [2017, 4, 20, 22, 29]
#
# ------bandlist------
# ['u10_time2273', 'v10_time2273']
# --------success-----
#
# ------time------
# [2017, 4, 20, 22, 28]
#
# ------bandlist------
# ['u10_time2273', 'v10_time2273']
# --------success-----
#
# ------time------
# [2017, 4, 20, 9, 57]
#
# ------bandlist------
# ['u10_time2271', 'v10_time2271']
# --------success-----
#
# ------time------
# [2017, 4, 20, 9, 57]
#
# ------bandlist------
# ['u10_time2271', 'v10_time2271']
# --------success-----
#
# ------time------
# [2017, 4, 19, 3, 2]
#
# ------bandlist------
# ['u10_time2266', 'v10_time2266']
# exception
# --------success-----
#
# ------time------
# [2017, 4, 18, 22, 50]
#
# ------bandlist------
# ['u10_time2265', 'v10_time2265']
# --------success-----
#
# ------time------
# [2017, 4, 18, 22, 50]
#
# ------bandlist------
# ['u10_time2265', 'v10_time2265']
# --------success-----
#
# ------time------
# [2017, 4, 18, 22, 49]
#
# ------bandlist------
# ['u10_time2265', 'v10_time2265']
# --------success-----
#
# ------time------
# [2017, 4, 18, 22, 49]
#
# ------bandlist------
# ['u10_time2265', 'v10_time2265']
# --------success-----
#
# ------time------
# [2017, 4, 18, 22, 48]
#
# ------bandlist------
# ['u10_time2265', 'v10_time2265']
# --------success-----
#
# ------time------
# [2017, 4, 18, 22, 46]
#
# ------bandlist------
# ['u10_time2265', 'v10_time2265']
# --------success-----
#
# ------time------
# [2017, 4, 18, 22, 45]
#
# ------bandlist------
# ['u10_time2265', 'v10_time2265']
# --------success-----
#
# ------time------
# [2017, 4, 18, 22, 45]
#
# ------bandlist------
# ['u10_time2265', 'v10_time2265']
# --------success-----
#
# ------time------
# [2017, 4, 18, 10, 13]
#
# ------bandlist------
# ['u10_time2263', 'v10_time2263']
# --------success-----
#
# ------time------
# [2017, 4, 17, 22, 3]
#
# ------bandlist------
# ['u10_time2261', 'v10_time2261']
# --------success-----
#
# ------time------
# [2017, 4, 17, 22, 3]
#
# ------bandlist------
# ['u10_time2261', 'v10_time2261']
# --------success-----
#
# ------time------
# [2017, 4, 17, 22, 2]
#
# ------bandlist------
# ['u10_time2261', 'v10_time2261']
# --------success-----
#
# ------time------
# [2017, 4, 17, 3, 19]
#
# ------bandlist------
# ['u10_time2258', 'v10_time2258']
# exception
# --------success-----
#
# ------time------
# [2017, 4, 17, 3, 18]
#
# ------bandlist------
# ['u10_time2258', 'v10_time2258']
# exception
# --------success-----
#
# ------time------
# [2017, 4, 16, 23, 5]
#
# ------bandlist------
# ['u10_time2257', 'v10_time2257']
# --------success-----
#
# ------time------
# [2017, 4, 16, 23, 4]
#
# ------bandlist------
# ['u10_time2257', 'v10_time2257']
# --------success-----
#
# ------time------
# [2017, 4, 16, 23, 4]
#
# ------bandlist------
# ['u10_time2257', 'v10_time2257']
# --------success-----
#
# ------time------
# [2017, 4, 16, 23, 3]
#
# ------bandlist------
# ['u10_time2257', 'v10_time2257']
# --------success-----
#
# ------time------
# [2017, 4, 16, 23, 3]
#
# ------bandlist------
# ['u10_time2257', 'v10_time2257']
# --------success-----
#
# ------time------
# [2017, 4, 16, 23, 3]
#
# ------bandlist------
# ['u10_time2257', 'v10_time2257']
# --------success-----
#
# ------time------
# [2017, 4, 16, 23, 2]
#
# ------bandlist------
# ['u10_time2257', 'v10_time2257']
# --------success-----
#
# ------time------
# [2017, 4, 16, 22, 17]
#
# ------bandlist------
# ['u10_time2257', 'v10_time2257']
# --------success-----
#
# ------time------
# [2017, 4, 16, 22, 17]
#
# ------bandlist------
# ['u10_time2257', 'v10_time2257']
# --------success-----
#
# ------time------
# [2017, 4, 15, 22, 20]
#
# ------bandlist------
# ['u10_time2253', 'v10_time2253']
# --------success-----
#
# ------time------
# [2017, 4, 15, 22, 20]
#
# ------bandlist------
# ['u10_time2253', 'v10_time2253']
# --------success-----
#
# ------time------
# [2017, 4, 15, 9, 49]
#
# ------bandlist------
# ['u10_time2251', 'v10_time2251']
# --------success-----
#
# ------time------
# [2017, 4, 15, 9, 49]
#
# ------bandlist------
# ['u10_time2251', 'v10_time2251']
# --------success-----
#
# ------time------
# [2017, 4, 15, 3, 35]
# ------bandlist------
# ['u10_time2250', 'v10_time2250']
# exception
# --------success-----
#
# ------time------
# [2017, 4, 14, 23, 23]
#
# ------bandlist------
# ['u10_time2249', 'v10_time2249']
# --------success-----
#
# ------time------
# [2017, 4, 14, 23, 20]
#
# ------bandlist------
# ['u10_time2249', 'v10_time2249']
# --------success-----
#
# ------time------
# [2017, 4, 14, 23, 20]
#
# ------bandlist------
# ['u10_time2249', 'v10_time2249']
# --------success-----
#
# ------time------
# [2017, 4, 13, 22, 42]
#
# ------bandlist------
# ['u10_time2245', 'v10_time2245']
# --------success-----
#
# ------time------
# [2017, 4, 13, 22, 41]
#
# ------bandlist------
# ['u10_time2245', 'v10_time2245']
# --------success-----
#
# ------time------
# [2017, 4, 13, 22, 41]
#
# ------bandlist------
# ['u10_time2245', 'v10_time2245']
# --------success-----
#
# ------time------
# [2017, 4, 13, 22, 41]
#
# ------bandlist------
# ['u10_time2245', 'v10_time2245']
# --------success-----
#
# ------time------
# [2017, 4, 13, 22, 40]
#
# ------bandlist------
# ['u10_time2245', 'v10_time2245']
# --------success-----
#
# ------time------
# [2017, 4, 13, 22, 37]
#
# ------bandlist------
# ['u10_time2245', 'v10_time2245']
# --------success-----
#
# ------time------
# [2017, 4, 13, 22, 37]
#
# ------bandlist------
# ['u10_time2245', 'v10_time2245']
# --------success-----
#
# ------time------
# [2017, 4, 13, 10, 5]
#
# ------bandlist------
# ['u10_time2243', 'v10_time2243']
# --------success-----
#
# ------time------
# [2017, 4, 13, 10, 5]
#
# ------bandlist------
# ['u10_time2243', 'v10_time2243']
# --------success-----
#
# ------time------
# [2017, 4, 13, 3, 51]
#
# ------bandlist------
# ['u10_time2242', 'v10_time2242']
# exception
# --------success-----
#
# ------time------
# [2017, 4, 13, 3, 51]
#
# ------bandlist------
# ['u10_time2242', 'v10_time2242']
# exception
# --------success-----
#
# ------time------
# [2017, 4, 13, 3, 50]
#
# ------bandlist------
# ['u10_time2242', 'v10_time2242']
# exception
# --------success-----
#
# ------time------
# [2017, 4, 12, 23, 36]
#
# ------bandlist------
# ['u10_time2241', 'v10_time2241']
# --------success-----
#
# ------time------
# [2017, 4, 12, 23, 35]
#
# ------bandlist------
# ['u10_time2241', 'v10_time2241']
# --------success-----
#
# ------time------
# [2017, 4, 11, 22, 53]
#
# ------bandlist------
# ['u10_time2237', 'v10_time2237']
# --------success-----
#
# ------time------
# [2017, 4, 11, 10, 21]
#
# ------bandlist------
# ['u10_time2235', 'v10_time2235']
# --------success-----
#
# ------time------
# [2017, 4, 11, 10, 21]
#
# ------bandlist------
# ['u10_time2235', 'v10_time2235']
# --------success-----
#
# ------time------
# [2017, 4, 11, 2, 28]
#
# ------bandlist------
# ['u10_time2233', 'v10_time2233']
# --------success-----
#
# ------time------
# [2017, 4, 10, 11, 18]
#
# ------bandlist------
# ['u10_time2231', 'v10_time2231']
# --------success-----
#
# ------time------
# [2017, 4, 10, 9, 41]
#
# ------bandlist------
# ['u10_time2231', 'v10_time2231']
# --------success-----
#
# ------time------
# [2017, 4, 10, 5, 4]
#
# ------bandlist------
# ['u10_time2230', 'v10_time2230']
# exception
# --------success-----
#
# ------time------
# [2017, 4, 9, 23, 13]
#
# ------bandlist------
# ['u10_time2229', 'v10_time2229']
# --------success-----
#
# ------time------
# [2017, 4, 9, 23, 12]
#
# ------bandlist------
# ['u10_time2229', 'v10_time2229']
# --------success-----
#
# ------time------
# [2017, 4, 9, 23, 12]
#
# ------bandlist------
# ['u10_time2229', 'v10_time2229']
# --------success-----
#
# ------time------
# [2017, 4, 9, 23, 11]
#
# ------bandlist------
# ['u10_time2229', 'v10_time2229']
# --------success-----
#
# ------time------
# [2017, 4, 8, 2, 54]
#
# ------bandlist------
# ['u10_time2221', 'v10_time2221']
# exception
# --------success-----
#
# ------time------
# [2017, 4, 8, 2, 54]
#
# ------bandlist------
# ['u10_time2221', 'v10_time2221']
# exception
# --------success-----
#
# ------time------
# [2017, 4, 8, 2, 53]
#
# ------bandlist------
# ['u10_time2221', 'v10_time2221']
# exception
# --------success-----
#
# ------time------
# [2017, 4, 7, 23, 28]
#
# ------bandlist------
# ['u10_time2221', 'v10_time2221']
# --------success-----
#
# ------time------
# [2017, 4, 7, 23, 27]
#
# ------bandlist------
# ['u10_time2221', 'v10_time2221']
# --------success-----
#
# ------time------
# [2017, 4, 7, 3, 2]
#
# ------bandlist------
# ['u10_time2218', 'v10_time2218']
# exception
# --------success-----
#
# ------time------
# [2017, 4, 5, 3, 19]
#
# ------bandlist------
# ['u10_time2210', 'v10_time2210']
# exception
# --------success-----
#
# ------time------
# [2017, 4, 5, 3, 18]
#
# ------bandlist------
# ['u10_time2210', 'v10_time2210']
# exception
# --------success-----
#
# ------time------
# [2017, 4, 3, 5, 11]
#
# ------bandlist------
# ['u10_time2202', 'v10_time2202']
# exception
# --------success-----
#
# ------time------
# [2017, 3, 29, 5, 4]
#
# ------bandlist------
# ['u10_time2182', 'v10_time2182']
# exception
# --------success-----
#
# ------time------
# [2017, 3, 27, 2, 54]
#
# ------bandlist------
# ['u10_time2173', 'v10_time2173']
# exception
# --------success-----
#
# ------time------
# [2017, 3, 27, 2, 54]
#
# ------bandlist------
# ['u10_time2173', 'v10_time2173']
# exception
# --------success-----
#
# ------time------
# [2017, 3, 27, 2, 53]
#
# ------bandlist------
# ['u10_time2173', 'v10_time2173']
# exception
# --------success-----
#
# ------time------
# [2017, 3, 26, 3, 2]
#
# ------bandlist------
# ['u10_time2170', 'v10_time2170']
# exception
# --------success-----
#
# ------time------
# [2017, 3, 24, 3, 18]
#
# ------bandlist------
# ['u10_time2162', 'v10_time2162']
# exception
# --------success-----
#
# ------time------
# [2017, 3, 20, 3, 51]
#
# ------bandlist------
# ['u10_time2146', 'v10_time2146']
# exception
# --------success-----
#
# ------time------
# [2017, 3, 20, 3, 50]
#
# ------bandlist------
# ['u10_time2146', 'v10_time2146']
# exception
# --------success-----
#
# ------time------
# [2017, 3, 17, 5, 4]
#
# ------bandlist------
# ['u10_time2134', 'v10_time2134']
# exception
# --------success-----
#
# ------time------
# [2017, 3, 10, 5, 11]
#
# ------bandlist------
# ['u10_time2106', 'v10_time2106']
# exception
# --------success-----
#
# ------time------
# [2017, 3, 8, 3, 51]
#
# ------bandlist------
# ['u10_time2098', 'v10_time2098']
# exception
# --------success-----
#
# ------time------
# [2017, 3, 8, 3, 50]
#
# ------bandlist------
# ['u10_time2098', 'v10_time2098']
# exception
# --------success-----
#
# ------time------
# [2017, 3, 5, 5, 4]
#
# ------bandlist------
# ['u10_time2086', 'v10_time2086']
# exception
# --------success-----
#
# ------time------
# [2017, 3, 3, 2, 54]
#
# ------bandlist------
# ['u10_time2077', 'v10_time2077']
# exception
# --------success-----
#
# ------time------
# [2017, 3, 3, 2, 54]
#
# ------bandlist------
# ['u10_time2077', 'v10_time2077']
# exception
# --------success-----
#
# ------time------
# [2017, 3, 3, 2, 53]
#
# ------bandlist------
# ['u10_time2077', 'v10_time2077']
# exception
# --------success-----
#
# ------time------
# [2017, 2, 26, 5, 11]
#
# ------bandlist------
# ['u10_time2058', 'v10_time2058']
# exception
# --------success-----
#
# ------time------
# [2017, 2, 26, 2, 45]
#
# ------bandlist------
# ['u10_time2057', 'v10_time2057']
# exception
# --------success-----
#
# ------time------
# [2017, 2, 24, 3, 51]
#
# ------bandlist------
# ['u10_time2050', 'v10_time2050']
# exception
# --------success-----
#
# ------time------
# [2017, 2, 24, 3, 50]
#
# ------bandlist------
# ['u10_time2050', 'v10_time2050']
# exception
# --------success-----
#
# ------time------
# [2017, 2, 20, 2, 44]
#
# ------bandlist------
# ['u10_time2033', 'v10_time2033']
# exception
# --------success-----
#
# ------time------
# [2017, 2, 9, 5, 4]
#
# ------bandlist------
# ['u10_time1990', 'v10_time1990']
# exception
# --------success-----
#
# ------time------
# [2017, 2, 2, 5, 11]
#
# ------bandlist------
# ['u10_time1962', 'v10_time1962']
# exception
# --------success-----
#
# ------time------
# [2017, 1, 31, 3, 51]
#
# ------bandlist------
# ['u10_time1954', 'v10_time1954']
# exception
# --------success-----
#
# ------time------
# [2017, 1, 31, 3, 50]
#
# ------bandlist------
# ['u10_time1954', 'v10_time1954']
# exception
# --------success-----
#
# ------time------
# [2017, 1, 27, 2, 44]
#
# ------bandlist------
# ['u10_time1937', 'v10_time1937']
# exception
# --------success-----
#
# ------time------
# [2017, 1, 16, 5, 4]
#
# ------bandlist------
# ['u10_time1894', 'v10_time1894']
# exception
# --------success-----
#
# ------time------
# [2017, 1, 9, 5, 11]
#
# ------bandlist------
# ['u10_time1866', 'v10_time1866']
# exception
# --------success-----
#
# ------time------
# [2017, 1, 7, 3, 51]
#
# ------bandlist------
# ['u10_time1858', 'v10_time1858']
# exception
# --------success-----
#
# ------time------
# [2017, 1, 7, 3, 50]
#
# ------bandlist------
# ['u10_time1858', 'v10_time1858']
# exception
# --------success-----
#
# ------time------
# [2017, 1, 3, 2, 44]
#
# ------bandlist------
# ['u10_time1841', 'v10_time1841']
# exception
# --------success-----
#
# ------time------
# [2016, 12, 30, 22, 3]
#
# ------bandlist------
# ['u10_time1829', 'v10_time1829']
# --------success-----
#
# ------time------
# [2016, 12, 30, 22, 3]
#
# ------bandlist------
# ['u10_time1829', 'v10_time1829']
# --------success-----
#
# ------time------
# [2016, 12, 28, 9, 49]
#
# ------bandlist------
# ['u10_time1819', 'v10_time1819']
# --------success-----
#
# ------time------
# [2016, 12, 26, 10, 5]
#
# ------bandlist------
# ['u10_time1811', 'v10_time1811']
# --------success-----
#
# ------time------
# [2016, 12, 26, 10, 5]
#
# ------bandlist------
# ['u10_time1811', 'v10_time1811']
# --------success-----

# %%
f = ProductIO.readProduct('../ecmwf/east02.nc')

# %%
band = f.getBand('u10_time2437')

# %%
databox2=np.zeros(1*1)

# %%
band.readPixels(10,10,1,1,databox2)
# Out:
# array([ 1.22391962])

# %%
band.readPixels(f.)

# %%
dd = f.getSceneGeoCoding()

# %%
pp = dd.getPixelPos(geopos(40, -50),None)

# %%
pp.x
# Out:
# 272.5

# %%
pp.y
# Out:
# 80.5

# %%
import numpy as np

# %% [markdown]
# mask out

# %%
file_list = []
with os.popen('cd /Volumes/Yangchao/sar_ecmwf/ \n ls *.dim') as file_lists:
    for f in file_lists:
        file_list.append(f[:-1])
        file_ecmwf = ProductIO.readProduct('/Volumes/Yangchao/sar_ecmwf/'+f[:-1])
        file_ecmwf_mask = calibrate.mask(file_ecmwf)
        ProductIO.writeProduct(file_ecmwf_mask, '/Volumes/Yangchao/sar_ecmwf_mask/'+f.split('.')[0], 'BEAM-DIMAP')
        file_ecmwf.dispose()
        file_ecmwf_mask.dispose()
        gc.collect()
        file_ = ProductIO.readProduct('/Volumes/Yangchao/Sentient/'+'_'.join(f[:-1].split('_')[1:]).split('.')[0]+'.zip')
        file_them_app = calibrate.thermal_app(file_)
        file_cali = calibrate.calibrate(file_them_app)
        file_mask = calibrate.mask(file_cali)
        ProductIO.writeProduct(file_mask, '/Volumes/Yangchao/sentinel_t_o_c_m/'+f.split('.')[0],'BEAM-DIMAP')
        file_.dispose()
        file_them_app.dispose()
        file_cali.dispose()
        file_mask.dispose()
        gc.collect()
np.save(file_list, 'file_list')
# Out:
# ----mask----
# ----thermal remove----
# ----apply orbit file----
# -----calibrate----
# ----mask----
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-145a039a3b1a> in <module>()
#      12         file_cali = calibrate.calibrate(file_them_app)
#      13         file_mask = calibrate.mask(file_cali)
# ---> 14         ProductIO.writeProduct(file_mask, '/Volumes/Yangchao/sentinel_t_o_c_m/'+f.split('.')[0],'BEAM-DIMAP')
#      15         file_.dispose()
#      16         file_them_app.dispose()
#
# RuntimeError: org.esa.snap.core.gpf.OperatorException: GC overhead limit exceeded

# %%
gc.collect()
# Out:
# 0
